# %% [markdown]
# >⚠️ Please don't "Run all". The last cell `server.display` has to be run manually after all the other cells have done running.
#
# # Visual Blocks Quick Start for Colab: Cartoonization  [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/google/visualblocks/blob/main/examples/quick_start_cartoonization.ipynb)
#
# Visual Blocks is a graphical development environment running in a Jupyter notebook cell. Create inteactive ML demos by mixing and matching built-in and custom blocks. Custom blocks call code found in other cells of the notebook.
#
# Visual Blocks is distributed as a Python package. To begin, install it with `!pip`.

# %%
# !pip install visualblocks

# %% [markdown]
# ##### Next write an inference function to visualize with Visual Blocks. Here we use the Tensorflow Lite interpreter with a CartoonGAN model to transform an image.

# %%
import numpy as np
import tensorflow as tf
import urllib.request

MODEL_URL = "https://storage.googleapis.com/tfweb/models/cartoongan_fp16.tflite"

with urllib.request.urlopen(MODEL_URL) as model:
  interpreter = tf.lite.Interpreter(model_content=model.read())

def cartoongan(tensors):
  """Inference function for use with Visual Blocks.

  This function is passed to the Visual Blocks server, which calls it to
  implement a Colab model runner block.

  Args:
    tensors: A list of np.ndarrays as input tensors. For this particular
    inference function, only the first item is used. The first item is the
    input image as a tensor of size 1x224x224x3 with floating point pixel
    values ranging from -1 to 1.

  Returns: 
    tensors: A list of np.ndarrays as input tensors. For this particular
    inference function, only the first item is used. The first item is the
    output image as a tensor of size 1x224x224x3 with uint8 pixel values.
  """

  interpreter.allocate_tensors()
  input_index = interpreter.get_input_details()[0]['index']
  get_input = interpreter.tensor(input_index)
  get_input()[:] = tensors[0].astype(get_input().dtype)

  interpreter.invoke()

  output_index = interpreter.get_output_details()[0]['index']
  get_output = interpreter.tensor(output_index)
  output = get_output()
  output += 1.0
  output *= 127.5
  np.clip(output, 0, 255, out=output)
  output = output.astype(np.uint8)

  return [output,]

# %% [markdown]
# ##### Then start a Visual Blocks server, passing it the inference function to use in a custom block.

# %%
import visualblocks
server = visualblocks.Server(generic=cartoongan)

# You can also pass multiple functions:
# server = visualblocks.Server(generic=(cartoongan, my_fn1), text_to_text=(my_fn2))

# %% [markdown]
# >⚠️ The following call has to be placed in a separate cell

# %%
server.display()
# Out:
# <style>
#     #pipeline-output-title {
#       margin-top: 12px;
#     }
#
#     #pipeline-output {
#       color: #999;
#       font-size: 11px;
#       margin: 4px 0;
#       max-height: 36px;
#       overflow-y: auto;
#       margin-bottom: 12px;
#       background-color: #f9f9f9;
#       border: 1px solid #ccc;
#       padding: 8px;
#       border-radius: 4px;
#     }
#
#     #pipeline-message {
#       font-size: 14px;
#       padding: 8px;
#       background-color: #ffefe1;
#       color: #99730a;
#       border: 1px solid #99730a;
#       border-radius: 4px;
#       width: fit-content;
#     }
#   </style>
# <div id="pipeline-output-title">Saved pipeline:</div>
# <div id="pipeline-output">N/A</div>
# <div id="pipeline-message"></div>
# <div id="ui-container"></div>
# {"project":{"id":"_","name":"Colab","creationTs":1680915153692,"lastModifiedTs":1680915153692},"graph":{"nodes":[{"id":"input_image_xw6hay","nodeSpecId":"input_image","customData":{"initialWidth":448,"initialHeight":240,"previewX":16,"previewY":16,"previewWidth":448,"previewHeight":240},"uiData":{"posX":256,"posY":112,"width":176,"selected":false},"propValues":{"urls":["https://storage.googleapis.com/tfweb/testpics/pose1.jpg","https://storage.googleapis.com/tfweb/testpics/dog.jpeg","https://storage.googleapis.com/tfweb/testpics/strawberry2.jpeg"],"gridColumnCount":3,"allowUserUpload":false,"selectedImageUrl":"https://storage.googleapis.com/tfweb/testpics/pose1.jpg","hidePreview":false}},{"id":"preprocess_image_m6spie","nodeSpecId":"preprocess_image","customData":{"previewX":480,"previewY":16,"previewWidth":320,"previewHeight":240},"uiData":{"posX":560,"posY":64,"width":176,"selected":false},"propValues":{"expandDim":true,"resize":{"width":224,"height":224},"resize,,,width":224,"resize,,,height":224,"normalize":{"fromMin":0,"fromMax":255,"toMin":-1,"toMax":1},"normalize,,,fromMin":0,"normalize,,,fromMax":255,"normalize,,,toMin":-1,"normalize,,,toMax":1},"incomingEdges":{"image":[{"sourceNodeId":"input_image_xw6hay","outputId":"image"}]}},{"id":"colab_model_runner_akrjxj","nodeSpecId":"colab_model_runner","customData":{"previewX":480,"previewY":16,"previewWidth":320,"previewHeight":240},"uiData":{"posX":832,"posY":128,"width":176,"selected":false},"inputValues":{"tensors":[]},"incomingEdges":{"tensors":[{"sourceNodeId":"preprocess_image_m6spie","outputId":"tensor"}]}},{"id":"crop_and_resize_mriie8","nodeSpecId":"crop_and_resize","customData":{"rightOfNode":"colab_model_runner_akrjxj","previewX":816,"previewY":16,"previewWidth":320,"previewHeight":240},"uiData":{"posX":1216,"posY":16,"width":176,"selected":false},"inputValues":{"cropRect":{"x1":-1,"y1":-1,"x2":-1,"y2":-1},"cropRect,,,x1":-1,"cropRect,,,y1":-1,"cropRect,,,x2":-1,"cropRect,,,y2":-1,"resize":{"width":-1,"height":-1},"resize,,,width":-1,"resize,,,height":-1},"incomingEdges":{"tensor":[{"sourceNodeId":"colab_model_runner_akrjxj","outputId":"firstTensor"}],"resize":[{"sourceNodeId":"get_image_size_iq16g9","outputId":"size"}]}},{"id":"get_image_size_iq16g9","nodeSpecId":"get_image_size","customData":{"rightOfNode":"input_image_xw6hay","previewX":816,"previewY":16,"previewWidth":320,"previewHeight":240},"uiData":{"posX":912,"posY":288,"width":176,"selected":false},"incomingEdges":{"image":[{"sourceNodeId":"input_image_xw6hay","outputId":"image"}]}},{"id":"tensor_to_image_1dye3c","nodeSpecId":"tensor_to_image","customData":{"rightOfNode":"colab_model_runner_akrjxj","previewX":480,"previewY":16,"previewWidth":320,"previewHeight":240},"uiData":{"posX":1536,"posY":112,"width":176,"selected":false},"propValues":{"hidePreview":false},"incomingEdges":{"tensor":[{"sourceNodeId":"crop_and_resize_mriie8","outputId":"tensor"}]}}]}}
# {"project":{"id":"_","name":"Colab","creationTs":1680915153692,"lastModifiedTs":1681842491288},"graph":{"nodes":[{"id":"input_image_xw6hay","nodeSpecId":"input_image","customData":{"initialWidth":448,"initialHeight":240,"previewX":16,"previewY":16,"previewWidth":448,"previewHeight":240},"uiData":{"posX":256,"posY":112,"width":176,"selected":true},"propValues":{"urls":["https://storage.googleapis.com/tfweb/testpics/pose1.jpg","https://storage.googleapis.com/tfweb/testpics/dog.jpeg","https://storage.googleapis.com/tfweb/testpics/strawberry2.jpeg"],"gridColumnCount":3,"allowUserUpload":false,"selectedImageUrl":"https://storage.googleapis.com/tfweb/testpics/dog.jpeg","hidePreview":false}},{"id":"preprocess_image_m6spie","nodeSpecId":"preprocess_image","customData":{"previewX":480,"previewY":16,"previewWidth":320,"previewHeight":240},"uiData":{"posX":560,"posY":64,"width":176,"selected":false},"propValues":{"expandDim":true,"resize":{"width":224,"height":224},"resize,,,width":224,"resize,,,height":224,"normalize":{"fromMin":0,"fromMax":255,"toMin":-1,"toMax":1},"normalize,,,fromMin":0,"normalize,,,fromMax":255,"normalize,,,toMin":-1,"normalize,,,toMax":1},"incomingEdges":{"image":[{"sourceNodeId":"input_image_xw6hay","outputId":"image"}]}},{"id":"crop_and_resize_mriie8","nodeSpecId":"crop_and_resize","customData":{"previewX":816,"previewY":16,"previewWidth":320,"previewHeight":240},"uiData":{"posX":1216,"posY":16,"width":176,"selected":false},"inputValues":{"cropRect":{"x1":-1,"y1":-1,"x2":-1,"y2":-1},"cropRect,,,x1":-1,"cropRect,,,y1":-1,"cropRect,,,x2":-1,"cropRect,,,y2":-1,"resize":{"width":-1,"height":-1},"resize,,,width":-1,"resize,,,height":-1},"incomingEdges":{"tensor":[{"sourceNodeId":"colab_model_runner_inpt6d","outputId":"firstTensor"}],"resize":[{"sourceNodeId":"get_image_size_iq16g9","outputId":"size"}]}},{"id":"get_image_size_iq16g9","nodeSpecId":"get_image_size","customData":{"previewX":816,"previewY":16,"previewWidth":320,"previewHeight":240},"uiData":{"posX":912,"posY":288,"width":176,"selected":false},"incomingEdges":{"image":[{"sourceNodeId":"input_image_xw6hay","outputId":"image"}]}},{"id":"tensor_to_image_1dye3c","nodeSpecId":"tensor_to_image","customData":{"previewX":480,"previewY":16,"previewWidth":320,"previewHeight":240},"uiData":{"posX":1536,"posY":112,"width":176,"selected":false},"propValues":{"hidePreview":false},"incomingEdges":{"tensor":[{"sourceNodeId":"crop_and_resize_mriie8","outputId":"tensor"}]}},{"id":"colab_model_runner_inpt6d","nodeSpecId":"colab_model_runner","customData":{"rightOfNode":"preprocess_image_m6spie","previewX":816,"previewY":16,"previewWidth":320,"previewHeight":240},"uiData":{"posX":864,"posY":96,"width":176,"selected":false},"propValues":{"function":"cartoongan"},"inputValues":{"tensors":[]},"incomingEdges":{"tensors":[{"sourceNodeId":"preprocess_image_m6spie","outputId":"tensor"}]}}]}}
